# %% [markdown]
# <a href="https://colab.research.google.com/github/BOINISHIVANANDAM/codeinza/blob/master/Project_A4_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/spMohanty/PlantVillage-Dataset
# Out:
# Cloning into 'PlantVillage-Dataset'...
# remote: Enumerating objects: 163229, done.
# remote: Total 163229 (delta 0), reused 0 (delta 0), pack-reused 163229
# Receiving objects: 100% (163229/163229), 2.00 GiB | 27.40 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Checking out files: 100% (182401/182401), done.

# %%
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix
import multiprocessing as mp
import shutil

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
import pandas.util.testing as tm
import pandas as pd
import numpy as np
import seaborn as sn

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
epochs = 30
batch_size = 150
testsplit = .2
targetx = 224
targety = 224
learning_rate = 0.0001
classes = 38
seed = random.randint(1, 1000)

data_dir = "/content/PlantVillage-Dataset/data_distribution_for_SVM/train/"
data_dir1 = "/content/PlantVillage-Dataset/data_distribution_for_SVM/test"

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        validation_split=testsplit,
        preprocessing_function=preprocess_input
)

train_generator = datagen.flow_from_directory(
        data_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=seed,
        subset="training"
)

test_generator = datagen.flow_from_directory(
        data_dir1,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=seed,
        subset="validation"
)
# Out:
# Found 7017 images belonging to 38 classes.
# Found 2094 images belonging to 38 classes.

# %%
img = train_generator.filepaths[np.random.random_integers(low=0, high=train_generator.samples)]
print(img)
img = mpimg.imread(img)
plt.imshow(img)
# Out:
# /content/PlantVillage-Dataset/data_distribution_for_SVM/train/20/b4d8b32b-6bf4-4b7d-b9fd-73819e1e8c77.JPG

# %%
checkpoint = ModelCheckpoint('dog_breed_classifier.h5',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             save_freq=1)

tensorboard =TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                            histogram_freq=0,
                            write_graph=False,
                            update_freq="epoch")
                            #save_freq=0)

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=20,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)

# %%
base_model = MobileNetV2(include_top=False, weights='imagenet', input_shape=(targetx, targety, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(1280, activation='relu',  kernel_initializer=glorot_uniform(seed), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(lr=learning_rate)
loss = "categorical_crossentropy"

for layer in model.layers:
    layer.trainable = True

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

model.summary()
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1280)         5120        global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1280)         1639680     batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 1280)         5120        dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 38)           48678       batch_normalization_1[0][0]
# ==================================================================================================
# Total params: 3,956,582
# Trainable params: 3,917,350
# Non-trainable params: 39,232
# __________________________________________________________________________________________________
# 0 input_1 True
# 1 Conv1_pad True
# 2 Conv1 True
# 3 bn_Conv1 True
# 4 Conv1_relu True
# 5 expanded_conv_depthwise True
# 6 expanded_conv_depthwise_BN True
# 7 expanded_conv_depthwise_relu True
# 8 expanded_conv_project True
# 9 expanded_conv_project_BN True
# 10 block_1_expand True
# 11 block_1_expand_BN True
# 12 block_1_expand_relu True
# 13 block_1_pad True
# 14 block_1_depthwise True
# 15 block_1_depthwise_BN True
# 16 block_1_depthwise_relu True
# 17 block_1_project True
# 18 block_1_project_BN True
# 19 block_2_expand True
# 20 block_2_expand_BN True
# 21 block_2_expand_relu True
# 22 block_2_depthwise True
# 23 block_2_depthwise_BN True
# 24 block_2_depthwise_relu True
# 25 block_2_project True
# 26 block_2_project_BN True
# 27 block_2_add True
# 28 block_3_expand True
# 29 block_3_expand_BN True
# 30 block_3_expand_relu True
# 31 block_3_pad True
# 32 block_3_depthwise True
# 33 block_3_depthwise_BN True
# 34 block_3_depthwise_relu True
# 35 block_3_project True
# 36 block_3_project_BN True
# 37 block_4_expand True
# 38 block_4_expand_BN True
# 39 block_4_expand_relu True
# 40 block_4_depthwise True
# 41 block_4_depthwise_BN True
# 42 block_4_depthwise_relu True
# 43 block_4_project True
# 44 block_4_project_BN True
# 45 block_4_add True
# 46 block_5_expand True
# 47 block_5_expand_BN True
# 48 block_5_expand_relu True
# 49 block_5_depthwise True
# 50 block_5_depthwise_BN True
# 51 block_5_depthwise_relu True
# 52 block_5_project True
# 53 block_5_project_BN True
# 54 block_5_add True
# 55 block_6_expand True
# 56 block_6_expand_BN True
# 57 block_6_expand_relu True
# 58 block_6_pad True
# 59 block_6_depthwise True
# 60 block_6_depthwise_BN True
# 61 block_6_depthwise_relu True
# 62 block_6_project True
# 63 block_6_project_BN True
# 64 block_7_expand True
# 65 block_7_expand_BN True
# 66 block_7_expand_relu True
# 67 block_7_depthwise True
# 68 block_7_depthwise_BN True
# 69 block_7_depthwise_relu True
# 70 block_7_project True
# 71 block_7_project_BN True
# 72 block_7_add True
# 73 block_8_expand True
# 74 block_8_expand_BN True
# 75 block_8_expand_relu True
# 76 block_8_depthwise True
# 77 block_8_depthwise_BN True
# 78 block_8_depthwise_relu True
# 79 block_8_project True
# 80 block_8_project_BN True
# 81 block_8_add True
# 82 block_9_expand True
# 83 block_9_expand_BN True
# 84 block_9_expand_relu True
# 85 block_9_depthwise True
# 86 block_9_depthwise_BN True
# 87 block_9_depthwise_relu True
# 88 block_9_project True
# 89 block_9_project_BN True
# 90 block_9_add True
# 91 block_10_expand True
# 92 block_10_expand_BN True
# 93 block_10_expand_relu True
# 94 block_10_depthwise True
# 95 block_10_depthwise_BN True
# 96 block_10_depthwise_relu True
# 97 block_10_project True
# 98 block_10_project_BN True
# 99 block_11_expand True
# 100 block_11_expand_BN True
# 101 block_11_expand_relu True
# 102 block_11_depthwise True
# 103 block_11_depthwise_BN True
# 104 block_11_depthwise_relu True
# 105 block_11_project True
# 106 block_11_project_BN True
# 107 block_11_add True
# 108 block_12_expand True
# 109 block_12_expand_BN True
# 110 block_12_expand_relu True
# 111 block_12_depthwise True
# 112 block_12_depthwise_BN True
# 113 block_12_depthwise_relu True
# 114 block_12_project True
# 115 block_12_project_BN True
# 116 block_12_add True
# 117 block_13_expand True
# 118 block_13_expand_BN True
# 119 block_13_expand_relu True
# 120 block_13_pad True
# 121 block_13_depthwise True
# 122 block_13_depthwise_BN True
# 123 block_13_depthwise_relu True
# 124 block_13_project True
# 125 block_13_project_BN True
# 126 block_14_expand True
# 127 block_14_expand_BN True
# 128 block_14_expand_relu True
# 129 block_14_depthwise True
# 130 block_14_depthwise_BN True
# 131 block_14_depthwise_relu True
# 132 block_14_project True
# 133 block_14_project_BN True
# 134 block_14_add True
# 135 block_15_expand True
# 136 block_15_expand_BN True
# 137 block_15_expand_relu True
# 138 block_15_depthwise True
# 139 block_15_depthwise_BN True
# 140 block_15_depthwise_relu True
# 141 block_15_project True
# 142 block_15_project_BN True
# 143 block_15_add True
# 144 block_16_expand True
# 145 block_16_expand_BN True
# 146 block_16_expand_relu True
# 147 block_16_depthwise True
# 148 block_16_depthwise_BN True
# 149 block_16_depthwise_relu True
# 150 block_16_project True
# 151 block_16_project_BN True
# 152 Conv_1 True
# 153 Conv_1_bn True
# 154 out_relu True
# 155 global_average_pooling2d True
# 156 batch_normalization True
# 157 dense True
# 158 batch_normalization_1 True
# 159 dense_1 True

# %%
# %%time

history = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator), 
                                validation_data=test_generator, 
                                validation_steps=len(test_generator),
                                epochs=epochs,
                                callbacks=[reducelr, earlystop, lambdacb, tensorboard, checkpoint])
# Out:
# WARNING:tensorflow:From <timed exec>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Learning rate:  1e-04
# Epoch 1/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 4.1742 - accuracy: 0.0200WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 20s - loss: 4.0261 - accuracy: 0.0367WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1825s vs `on_train_batch_end` time: 0.7120s). Check your callbacks.
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 44s - loss: 3.8667 - accuracy: 0.0556WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 54s - loss: 3.6795 - accuracy: 0.1083WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 59s - loss: 3.5117 - accuracy: 0.1533WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:02 - loss: 3.3413 - accuracy: 0.1922WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:04 - loss: 3.1926 - accuracy: 0.2295WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:04 - loss: 3.0554 - accuracy: 0.2608WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:04 - loss: 2.9359 - accuracy: 0.2867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:04 - loss: 2.8304 - accuracy: 0.3100WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:03 - loss: 2.7430 - accuracy: 0.3333WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:03 - loss: 2.6300 - accuracy: 0.3606WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:02 - loss: 2.5718 - accuracy: 0.3730WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:00 - loss: 2.4977 - accuracy: 0.3909WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 58s - loss: 2.4319 - accuracy: 0.4055 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 57s - loss: 2.3547 - accuracy: 0.4221WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 56s - loss: 2.2961 - accuracy: 0.4327WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 54s - loss: 2.2424 - accuracy: 0.4454WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 52s - loss: 2.1937 - accuracy: 0.4562WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 51s - loss: 2.1453 - accuracy: 0.4692WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 49s - loss: 2.0940 - accuracy: 0.4828WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 47s - loss: 2.0499 - accuracy: 0.4928WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 46s - loss: 2.0019 - accuracy: 0.5060WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 44s - loss: 1.9647 - accuracy: 0.5153WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 42s - loss: 1.9181 - accuracy: 0.5268WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 40s - loss: 1.8778 - accuracy: 0.5358WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 38s - loss: 1.8402 - accuracy: 0.5434WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 1.7988 - accuracy: 0.5544WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 1.7686 - accuracy: 0.5610WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 1.7372 - accuracy: 0.5686WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 1.7042 - accuracy: 0.5766WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 1.6684 - accuracy: 0.5853WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 1.6354 - accuracy: 0.5939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 1.6043 - accuracy: 0.6017WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 1.5769 - accuracy: 0.6080WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 1.5503 - accuracy: 0.6143WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 1.5302 - accuracy: 0.6185WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 1.5031 - accuracy: 0.6247WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 1.4815 - accuracy: 0.6295WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 1.4583 - accuracy: 0.6350WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 1.4335 - accuracy: 0.6412WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 1.4144 - accuracy: 0.6451 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 1.3922 - accuracy: 0.6517WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 1.3719 - accuracy: 0.6568WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 1.3505 - accuracy: 0.6622WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 1s - loss: 1.3304 - accuracy: 0.6665WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 122s 3s/step - loss: 1.3081 - accuracy: 0.6724 - val_loss: 2.2857 - val_accuracy: 0.4709
# Learning rate:  1e-04
# Epoch 2/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.2979 - accuracy: 0.9333WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 46s - loss: 0.3428 - accuracy: 0.9133WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 1:00 - loss: 0.3348 - accuracy: 0.9200WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:06 - loss: 0.3380 - accuracy: 0.9183WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:09 - loss: 0.3345 - accuracy: 0.9187WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:10 - loss: 0.3388 - accuracy: 0.9111WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:10 - loss: 0.3350 - accuracy: 0.9086WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:10 - loss: 0.3279 - accuracy: 0.9125WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:09 - loss: 0.3203 - accuracy: 0.9156WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:08 - loss: 0.3120 - accuracy: 0.9193WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:07 - loss: 0.3033 - accuracy: 0.9224WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:05 - loss: 0.3054 - accuracy: 0.9233WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:04 - loss: 0.3018 - accuracy: 0.9246WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:02 - loss: 0.2997 - accuracy: 0.9243WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:01 - loss: 0.2911 - accuracy: 0.9271WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 59s - loss: 0.2905 - accuracy: 0.9262 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 57s - loss: 0.2848 - accuracy: 0.9290WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 56s - loss: 0.2845 - accuracy: 0.9296WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 54s - loss: 0.2811 - accuracy: 0.9302WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 52s - loss: 0.2801 - accuracy: 0.9310WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 50s - loss: 0.2784 - accuracy: 0.9314WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 48s - loss: 0.2783 - accuracy: 0.9312WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 47s - loss: 0.2785 - accuracy: 0.9301WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 45s - loss: 0.2744 - accuracy: 0.9317WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 42s - loss: 0.2737 - accuracy: 0.9319WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 41s - loss: 0.2731 - accuracy: 0.9320WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.2705 - accuracy: 0.9325WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.2670 - accuracy: 0.9335WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.2623 - accuracy: 0.9347WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.2600 - accuracy: 0.9349WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.2577 - accuracy: 0.9355WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.2555 - accuracy: 0.9358WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.2543 - accuracy: 0.9361WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.2517 - accuracy: 0.9368WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.2505 - accuracy: 0.9366WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.2502 - accuracy: 0.9363WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.2488 - accuracy: 0.9366WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.2477 - accuracy: 0.9368WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.2465 - accuracy: 0.9371WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.2449 - accuracy: 0.9377WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.2433 - accuracy: 0.9379WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.2415 - accuracy: 0.9381 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.2435 - accuracy: 0.9377WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.2424 - accuracy: 0.9380WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 0.2411 - accuracy: 0.9387WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 2s - loss: 0.2385 - accuracy: 0.9393WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 119s 3s/step - loss: 0.2378 - accuracy: 0.9391 - val_loss: 1.8580 - val_accuracy: 0.5234
# Learning rate:  1e-04
# Epoch 3/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.1038 - accuracy: 0.9733WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 33s - loss: 0.1096 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 53s - loss: 0.1241 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:01 - loss: 0.1303 - accuracy: 0.9665WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:04 - loss: 0.1345 - accuracy: 0.9665WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:06 - loss: 0.1361 - accuracy: 0.9654WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:07 - loss: 0.1336 - accuracy: 0.9656WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:07 - loss: 0.1345 - accuracy: 0.9674WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:07 - loss: 0.1295 - accuracy: 0.9689WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:06 - loss: 0.1280 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:05 - loss: 0.1235 - accuracy: 0.9709WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:04 - loss: 0.1215 - accuracy: 0.9717WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:03 - loss: 0.1232 - accuracy: 0.9708WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:01 - loss: 0.1250 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:00 - loss: 0.1245 - accuracy: 0.9698WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 58s - loss: 0.1260 - accuracy: 0.9696 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 57s - loss: 0.1225 - accuracy: 0.9710WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 55s - loss: 0.1242 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 53s - loss: 0.1253 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 51s - loss: 0.1252 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 50s - loss: 0.1244 - accuracy: 0.9708WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 48s - loss: 0.1256 - accuracy: 0.9700WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 46s - loss: 0.1241 - accuracy: 0.9701WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 44s - loss: 0.1234 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 42s - loss: 0.1228 - accuracy: 0.9704WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 40s - loss: 0.1214 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.1227 - accuracy: 0.9701WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.1214 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.1201 - accuracy: 0.9708WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.1207 - accuracy: 0.9702WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.1193 - accuracy: 0.9708WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.1174 - accuracy: 0.9717WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.1174 - accuracy: 0.9713WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.1174 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.1166 - accuracy: 0.9716WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.1170 - accuracy: 0.9709WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.1167 - accuracy: 0.9710WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.1162 - accuracy: 0.9714WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.1157 - accuracy: 0.9713WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.1163 - accuracy: 0.9712WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.1164 - accuracy: 0.9707WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.1164 - accuracy: 0.9708 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.1168 - accuracy: 0.9707WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.1172 - accuracy: 0.9703WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 0.1164 - accuracy: 0.9705WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 1s - loss: 0.1166 - accuracy: 0.9706WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 119s 3s/step - loss: 0.1158 - accuracy: 0.9711 - val_loss: 1.6124 - val_accuracy: 0.5492
# Learning rate:  1e-04
# Epoch 4/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.0607 - accuracy: 0.9800WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 46s - loss: 0.0570 - accuracy: 0.9900WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 1:00 - loss: 0.0564 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:05 - loss: 0.0657 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:08 - loss: 0.0684 - accuracy: 0.9827WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:09 - loss: 0.0707 - accuracy: 0.9822WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:10 - loss: 0.0674 - accuracy: 0.9848WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:10 - loss: 0.0678 - accuracy: 0.9850WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:09 - loss: 0.0664 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:08 - loss: 0.0654 - accuracy: 0.9873WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:07 - loss: 0.0653 - accuracy: 0.9873WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:05 - loss: 0.0662 - accuracy: 0.9861WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:04 - loss: 0.0644 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:02 - loss: 0.0634 - accuracy: 0.9876WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:01 - loss: 0.0647 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 59s - loss: 0.0653 - accuracy: 0.9871 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 57s - loss: 0.0667 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 56s - loss: 0.0671 - accuracy: 0.9863WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 54s - loss: 0.0670 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 52s - loss: 0.0661 - accuracy: 0.9870WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 50s - loss: 0.0670 - accuracy: 0.9863WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 48s - loss: 0.0664 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 47s - loss: 0.0660 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 45s - loss: 0.0658 - accuracy: 0.9864WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 43s - loss: 0.0655 - accuracy: 0.9869WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 41s - loss: 0.0649 - accuracy: 0.9869WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.0644 - accuracy: 0.9872WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.0656 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.0651 - accuracy: 0.9869WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.0656 - accuracy: 0.9869WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.0653 - accuracy: 0.9869WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.0651 - accuracy: 0.9871WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.0651 - accuracy: 0.9873WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.0646 - accuracy: 0.9875WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.0646 - accuracy: 0.9874WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.0635 - accuracy: 0.9878WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.0635 - accuracy: 0.9877WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.0632 - accuracy: 0.9879WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.0631 - accuracy: 0.9881WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.0628 - accuracy: 0.9883WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.0624 - accuracy: 0.9884WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.0625 - accuracy: 0.9882 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.0626 - accuracy: 0.9882WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.0628 - accuracy: 0.9881WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 0.0624 - accuracy: 0.9882WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 1s - loss: 0.0624 - accuracy: 0.9881WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 119s 3s/step - loss: 0.0624 - accuracy: 0.9880 - val_loss: 1.4195 - val_accuracy: 0.5989
# Learning rate:  1e-04
# Epoch 5/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.0276 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 46s - loss: 0.0402 - accuracy: 0.9967WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 1:00 - loss: 0.0446 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:06 - loss: 0.0442 - accuracy: 0.9917WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:09 - loss: 0.0449 - accuracy: 0.9907WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:10 - loss: 0.0467 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:10 - loss: 0.0448 - accuracy: 0.9924WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:10 - loss: 0.0447 - accuracy: 0.9925WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:10 - loss: 0.0421 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:08 - loss: 0.0415 - accuracy: 0.9940WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:07 - loss: 0.0399 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:06 - loss: 0.0409 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:04 - loss: 0.0421 - accuracy: 0.9938WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:03 - loss: 0.0413 - accuracy: 0.9943WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:01 - loss: 0.0409 - accuracy: 0.9947WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 59s - loss: 0.0426 - accuracy: 0.9937 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 58s - loss: 0.0433 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 56s - loss: 0.0433 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 54s - loss: 0.0440 - accuracy: 0.9930WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 52s - loss: 0.0433 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 51s - loss: 0.0429 - accuracy: 0.9937WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 49s - loss: 0.0426 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 47s - loss: 0.0421 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 45s - loss: 0.0424 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 43s - loss: 0.0423 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 41s - loss: 0.0429 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.0426 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.0428 - accuracy: 0.9928WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.0434 - accuracy: 0.9924WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.0432 - accuracy: 0.9924WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.0429 - accuracy: 0.9924WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.0432 - accuracy: 0.9924WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.0431 - accuracy: 0.9923WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.0425 - accuracy: 0.9925WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.0419 - accuracy: 0.9927WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.0419 - accuracy: 0.9925WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.0421 - accuracy: 0.9924WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.0427 - accuracy: 0.9922WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.0424 - accuracy: 0.9923WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.0425 - accuracy: 0.9921WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.0426 - accuracy: 0.9922WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.0421 - accuracy: 0.9923 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.0416 - accuracy: 0.9925WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.0418 - accuracy: 0.9925WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 4s - loss: 0.0417 - accuracy: 0.9926WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 2s - loss: 0.0418 - accuracy: 0.9926WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 120s 3s/step - loss: 0.0423 - accuracy: 0.9923 - val_loss: 1.3293 - val_accuracy: 0.6189
# Learning rate:  1e-04
# Epoch 6/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.0459 - accuracy: 0.9867WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 45s - loss: 0.0375 - accuracy: 0.9900WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 1:00 - loss: 0.0385 - accuracy: 0.9911WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:06 - loss: 0.0384 - accuracy: 0.9900WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:08 - loss: 0.0376 - accuracy: 0.9907WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:09 - loss: 0.0354 - accuracy: 0.9922WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:10 - loss: 0.0330 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:09 - loss: 0.0326 - accuracy: 0.9933WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:09 - loss: 0.0310 - accuracy: 0.9941WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:08 - loss: 0.0309 - accuracy: 0.9940WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:06 - loss: 0.0309 - accuracy: 0.9939WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:05 - loss: 0.0299 - accuracy: 0.9944WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:04 - loss: 0.0292 - accuracy: 0.9949WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:02 - loss: 0.0290 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:01 - loss: 0.0287 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 59s - loss: 0.0286 - accuracy: 0.9954 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 57s - loss: 0.0282 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 56s - loss: 0.0284 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 54s - loss: 0.0288 - accuracy: 0.9954WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 52s - loss: 0.0293 - accuracy: 0.9950WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 50s - loss: 0.0292 - accuracy: 0.9949WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 48s - loss: 0.0287 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 47s - loss: 0.0295 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 45s - loss: 0.0294 - accuracy: 0.9950WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 43s - loss: 0.0289 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 41s - loss: 0.0293 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.0293 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.0298 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.0299 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.0298 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.0299 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.0302 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.0301 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.0305 - accuracy: 0.9953WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.0303 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.0301 - accuracy: 0.9952WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.0301 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.0300 - accuracy: 0.9951WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.0302 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.0300 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.0302 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.0300 - accuracy: 0.9949 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.0303 - accuracy: 0.9949WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.0301 - accuracy: 0.9950WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 0.0303 - accuracy: 0.9949WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 1s - loss: 0.0307 - accuracy: 0.9948WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# ...
# Learning rate:  1e-04
# Epoch 29/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 46s - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 59s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:05 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:08 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:10 - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:10 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:10 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:09 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:08 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:07 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:05 - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:04 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:02 - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:01 - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 59s - loss: 0.0012 - accuracy: 1.0000 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 57s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 56s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 54s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 52s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 50s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 48s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 46s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 44s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 42s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 41s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.0011 - accuracy: 1.0000 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 1s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 119s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.9427
# Learning rate:  1e-04
# Epoch 30/30
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  1/47 [..............................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  2/47 [>.............................] - ETA: 47s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  3/47 [>.............................] - ETA: 1:00 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  4/47 [=>............................] - ETA: 1:06 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  5/47 [==>...........................] - ETA: 1:09 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  6/47 [==>...........................] - ETA: 1:10 - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  7/47 [===>..........................] - ETA: 1:10 - loss: 9.4411e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  8/47 [====>.........................] - ETA: 1:10 - loss: 8.8715e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
#  9/47 [====>.........................] - ETA: 1:09 - loss: 8.9879e-04 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 10/47 [=====>........................] - ETA: 1:08 - loss: 0.0012 - accuracy: 1.0000    WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 11/47 [======>.......................] - ETA: 1:07 - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 12/47 [======>.......................] - ETA: 1:06 - loss: 0.0012 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 13/47 [=======>......................] - ETA: 1:04 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 14/47 [=======>......................] - ETA: 1:03 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 15/47 [========>.....................] - ETA: 1:01 - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 16/47 [=========>....................] - ETA: 59s - loss: 0.0011 - accuracy: 1.0000 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 17/47 [=========>....................] - ETA: 58s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 18/47 [==========>...................] - ETA: 56s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 19/47 [===========>..................] - ETA: 54s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 20/47 [===========>..................] - ETA: 52s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 21/47 [============>.................] - ETA: 51s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 22/47 [=============>................] - ETA: 49s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 23/47 [=============>................] - ETA: 47s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 24/47 [==============>...............] - ETA: 45s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 25/47 [==============>...............] - ETA: 43s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 26/47 [===============>..............] - ETA: 41s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 27/47 [================>.............] - ETA: 39s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 28/47 [================>.............] - ETA: 37s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 29/47 [=================>............] - ETA: 35s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 30/47 [==================>...........] - ETA: 33s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 31/47 [==================>...........] - ETA: 31s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 32/47 [===================>..........] - ETA: 29s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 33/47 [====================>.........] - ETA: 27s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 34/47 [====================>.........] - ETA: 25s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 35/47 [=====================>........] - ETA: 23s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 36/47 [=====================>........] - ETA: 21s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 37/47 [======================>.......] - ETA: 19s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 38/47 [=======================>......] - ETA: 17s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 39/47 [=======================>......] - ETA: 15s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 40/47 [========================>.....] - ETA: 13s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 41/47 [=========================>....] - ETA: 11s - loss: 0.0011 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 42/47 [=========================>....] - ETA: 9s - loss: 0.0010 - accuracy: 1.0000 WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 43/47 [==========================>...] - ETA: 7s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 44/47 [===========================>..] - ETA: 5s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 45/47 [===========================>..] - ETA: 3s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 46/47 [============================>.] - ETA: 2s - loss: 0.0010 - accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 47/47 [==============================] - 120s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9398
# CPU times: user 1h 9min 21s, sys: 5min 4s, total: 1h 14min 26s
# Wall time: 1h 1min 5s

# %%
plt.subplot(1, 2, 1)
plt.title('Training and test accuracy')
plt.plot(history.epoch, history.history['accuracy'], label='Training accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], label='Test accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.title('Training and test loss')
plt.plot(history.epoch, history.history['loss'], label='Training loss')
plt.plot(history.epoch, history.history['val_loss'], label='Test loss')
plt.legend()

plt.show()

# %%
test_generator.reset()
predictions = model.predict_generator(test_generator, steps=len(test_generator))
y = np.argmax(predictions, axis=1)

print('Classification Report')
cr = classification_report(y_true=test_generator.classes, y_pred=y, target_names=test_generator.class_indices)
print(cr)
# Out:
# WARNING:tensorflow:From <ipython-input-13-6c336b480794>:2: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        22
#            1       1.00      1.00      1.00        17
#           10       1.00      1.00      1.00        44
#           11       0.95      0.95      0.95        44
#           12       0.98      0.96      0.97        46
#           13       1.00      1.00      1.00        44
#           14       0.94      1.00      0.97        15
#           15       1.00      1.00      1.00       233
#           16       1.00      0.98      0.99        88
#           17       0.67      1.00      0.80         4
#           18       0.95      0.72      0.82        25
#           19       0.92      0.98      0.95        60
#            2       1.00      0.92      0.96        12
#           20       1.00      1.00      1.00        44
#           21       1.00      0.70      0.82        40
#           22       0.22      0.67      0.33         3
#           23       1.00      0.92      0.96        36
#           24       0.96      1.00      0.98       179
#           25       1.00      1.00      1.00        75
#           26       1.00      1.00      1.00        38
#           27       0.80      1.00      0.89        20
#           28       0.97      0.85      0.91        92
#           29       0.81      0.36      0.50        36
#            3       0.94      0.94      0.94        53
#           30       0.92      0.84      0.88        73
#           31       0.85      0.82      0.84        28
#           32       0.69      0.95      0.80        62
#           33       0.84      1.00      0.91        68
#           34       0.85      0.88      0.87        51
#           35       0.98      1.00      0.99       220
#           36       0.83      1.00      0.91        15
#           37       1.00      0.97      0.98        67
#            4       0.96      1.00      0.98        45
#            5       1.00      0.93      0.97        45
#            6       1.00      1.00      1.00        40
#            7       0.93      0.70      0.80        20
#            8       0.98      1.00      0.99        46
#            9       0.90      0.98      0.93        44
#
#     accuracy                           0.95      2094
#    macro avg       0.92      0.92      0.91      2094
# weighted avg       0.95      0.95      0.95      2094

# %%
print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, y)
df = pd.DataFrame(cm, columns=test_generator.class_indices)
plt.figure(figsize=(80,80))
sn.heatmap(df, annot=True)
# Out:
# Confusion Matrix
